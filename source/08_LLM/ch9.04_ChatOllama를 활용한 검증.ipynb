# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
# - pip install langchain-ollama
# - pip install langchain-community

# %%
# %pip install -q langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. LLM 답변 생성
# - https://ollama.com/ 에서 모델 선택(llama3.2:1b)
# - powershell이나 cmd창에서 ollama pull llama3.2:1b

# %%
from langchain_ollama import ChatOllama
# from langchain_community.chat_models import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
ai_message = llm.invoke("2020년 월드 시리즈에서 누가 우승했나요?")
ai_message.content
# Out:
# '2020 년 월드 시리즈는 한국에서 열렸고, 두 đội의 대표 선수가 tham gia했습니다.  이 대회는 5월에 진행되었습니다. 이 대회에서, 일본은 3-2로 우승하여 세계적인 수준의 cầu수인 세리오프 카마코와 나카hiro 미즈노를 상대로 승리했습니다.'

# %% [markdown]
# # 3. 코랩에서 ollama(exaone3.5:2.4b)돌리기
# http://bit.ly/3lKpnVH
