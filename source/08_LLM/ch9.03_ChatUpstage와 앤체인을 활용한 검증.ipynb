# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
# - pip install openai langchain-upstage

# %%
# %pip install -q langchain-upstage
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM 답변 생성
# ## 2.1 OpenAI SDK

# %%
from openai import OpenAI # openai==1.52.2
import os
upstage_api_key = os.getenv("UPSTAGE_API_KEY")

client = OpenAI(
    api_key=upstage_api_key,
    base_url="https://api.upstage.ai/v1"
)
stream = client.chat.completions.create(
    model="solar-pro2",
    messages=[
        {
            "role": "user",
            "content": "2020년 월드 시리즈 누가 우승했어?"
        }
    ],
    stream=False,
)

# %%
print(stream.choices[0].message.content)
# Out:
# 2020년 월드 시리즈에서는 **로스앤젤레스 다저스**가 우승했습니다.
#
# - **상대 팀**: 탬파베이 레이스
# - **시리즈 결과**: 다저스 4승 2패로 승리
# - **MVP**: 다저스의 투수 **클레이턴 커쇼**(Clayton Kershaw)가 시리즈에서 뛰어난 활약을 펼쳤으나, 공식 MVP는 **조지아 스프링어**(George Springer, 탬파베이 소속)가 수상했습니다.
#
# 이는 다저스의 32년 만의 첫 월드 시리즈 우승이었습니다. 2020 시즌은 코로나19 영향으로 짧은 기간(정규 시즌 60경기)에 진행되었지만, 다저스는 강력한 팀력을 보여주며 우승을 차지했습니다.

# %% [markdown]
# # 2.2 LangChain을 선택
# - 발급받은 API Key를 .env에 UPSTAGE_API_KEY라고 저장하면 별도의 설정없이 ChatUpstage를 바로 사용

# %%
from langchain_upstage import ChatUpstage
from langchain_core.messages import SystemMessage, HumanMessage
llm = ChatUpstage()
messages=[
    SystemMessage(content="너는 친절하게 대답해 주는 비서야"),
    HumanMessage(content="2020년 월드 시리즈 누가 우승했어?")
]
ai_message = llm.invoke(input=messages)
ai_message
# Out:
# AIMessage(content='2020년 월드 시리즈는 LA 다저스가 우승했습니다. 그들은 탬파베이 레이스를 4승 2패로 꺾고 32년 만에 월드시리즈 우승을 차지했습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 36, 'total_tokens': 80, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': '90335309-c1ba-40ba-8561-0ff416ef3ecf', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--6ef0048f-2121-4e48-9902-8ce019f78c81-0', usage_metadata={'input_tokens': 36, 'output_tokens': 44, 'total_tokens': 80, 'input_token_details': {}, 'output_token_details': {}})
