# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets import mnist #mnist 훈련셋과 테스트셋
from tensorflow.keras.utils import to_categorical #원핫인코딩
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from matplotlib import pyplot as plt #학습과정 loss와 acc시각화

# %%
# 1. 데이터 셋
width = 28; height=28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
plt_row = 3
plt_col = 10
#plt.fugure(figsize=(plt_col, plt_row))
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
#plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
# axes[0,0].imshow(X_test[0].reshape(width, height))
# axes[0,0].axis('off')
# title = '실제:{}'.format(y_test[0])
# axes[0,0].set_title(title)
#plt.subplots_adjust(hspace=0.4, wspace=0.3)
for i in range(plt_row*plt_col):
    subax = axes[i//plt_col, i%plt_col] # //:몫연산자, %:나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = '실제:{}'.format(y_test[i])
    subax.set_title(title)
plt.tight_layout()

# %% [markdown]
# # 1. DNN

# %%
# %%time
#1. 데이터 생성 및 전처리
width = 28; height=28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
#독립변수 (28*28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype('float32')/255.0
X_val = X_val.reshape(-1, width*height).astype('float32')/255.0
X_test = X_test.reshape(-1, width*height).astype('float32')/255.0
#타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
#2. 모델 구성
model = Sequential([
    Input(shape=(width*height,)),
    Dense(units=1024, activation='relu'),
    Dropout(0.3),
    Dense(units=512, activation='relu'),
    Dropout(0.3),
    Dense(units=256, activation='relu'),
    Dropout(0.3),
    Dense(units=10, activation='softmax')
])
# model.summary()
#3. 학습설정
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 4. 학습
model.fit(X_train, Y_train, 
          epochs=50, 
          validation_data=(X_val, Y_val),
         verbose=1)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 20s 12ms/step - loss: 0.2794 - accuracy: 0.9164 - val_loss: 0.1342 - val_accuracy: 0.9599
# Epoch 2/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.1417 - accuracy: 0.9598 - val_loss: 0.1029 - val_accuracy: 0.9698
# Epoch 3/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.1186 - accuracy: 0.9665 - val_loss: 0.0919 - val_accuracy: 0.9729
# Epoch 4/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0943 - accuracy: 0.9726 - val_loss: 0.0987 - val_accuracy: 0.9723
# Epoch 5/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0893 - accuracy: 0.9737 - val_loss: 0.0860 - val_accuracy: 0.9786
# Epoch 6/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0784 - accuracy: 0.9775 - val_loss: 0.1072 - val_accuracy: 0.9744
# Epoch 7/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0743 - accuracy: 0.9798 - val_loss: 0.0943 - val_accuracy: 0.9758
# Epoch 8/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0633 - accuracy: 0.9814 - val_loss: 0.1025 - val_accuracy: 0.9771
# Epoch 9/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0606 - accuracy: 0.9822 - val_loss: 0.0932 - val_accuracy: 0.9788
# Epoch 10/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0631 - accuracy: 0.9828 - val_loss: 0.0786 - val_accuracy: 0.9801
# Epoch 11/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0555 - accuracy: 0.9847 - val_loss: 0.1090 - val_accuracy: 0.9778
# Epoch 12/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0544 - accuracy: 0.9841 - val_loss: 0.1148 - val_accuracy: 0.9766
# Epoch 13/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0538 - accuracy: 0.9855 - val_loss: 0.0874 - val_accuracy: 0.9806
# Epoch 14/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0483 - accuracy: 0.9867 - val_loss: 0.1093 - val_accuracy: 0.9786
# Epoch 15/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0519 - accuracy: 0.9868 - val_loss: 0.0999 - val_accuracy: 0.9797
# Epoch 16/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0492 - accuracy: 0.9871 - val_loss: 0.0932 - val_accuracy: 0.9800
# Epoch 17/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0467 - accuracy: 0.9874 - val_loss: 0.1193 - val_accuracy: 0.9815
# Epoch 18/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0479 - accuracy: 0.9880 - val_loss: 0.1043 - val_accuracy: 0.9786
# Epoch 19/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0434 - accuracy: 0.9886 - val_loss: 0.0985 - val_accuracy: 0.9815
# Epoch 20/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0424 - accuracy: 0.9890 - val_loss: 0.1067 - val_accuracy: 0.9807
# Epoch 21/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0514 - accuracy: 0.9876 - val_loss: 0.1053 - val_accuracy: 0.9796
# Epoch 22/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0434 - accuracy: 0.9893 - val_loss: 0.1034 - val_accuracy: 0.9809
# Epoch 23/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0403 - accuracy: 0.9897 - val_loss: 0.1088 - val_accuracy: 0.9834
# Epoch 24/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0430 - accuracy: 0.9897 - val_loss: 0.1292 - val_accuracy: 0.9784
# Epoch 25/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0397 - accuracy: 0.9897 - val_loss: 0.1105 - val_accuracy: 0.9808
# Epoch 26/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0413 - accuracy: 0.9900 - val_loss: 0.1315 - val_accuracy: 0.9805
# Epoch 27/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0453 - accuracy: 0.9901 - val_loss: 0.1239 - val_accuracy: 0.9807
# Epoch 28/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0397 - accuracy: 0.9903 - val_loss: 0.1226 - val_accuracy: 0.9818
# Epoch 29/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0354 - accuracy: 0.9914 - val_loss: 0.1281 - val_accuracy: 0.9806
# Epoch 30/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0374 - accuracy: 0.9915 - val_loss: 0.1299 - val_accuracy: 0.9821
# Epoch 31/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0427 - accuracy: 0.9902 - val_loss: 0.1414 - val_accuracy: 0.9801
# Epoch 32/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0395 - accuracy: 0.9917 - val_loss: 0.1374 - val_accuracy: 0.9783
# Epoch 33/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0367 - accuracy: 0.9917 - val_loss: 0.1497 - val_accuracy: 0.9791
# Epoch 34/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0362 - accuracy: 0.9916 - val_loss: 0.1419 - val_accuracy: 0.9818
# Epoch 35/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0394 - accuracy: 0.9909 - val_loss: 0.1497 - val_accuracy: 0.9806
# Epoch 36/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0481 - accuracy: 0.9907 - val_loss: 0.1362 - val_accuracy: 0.9828
# Epoch 37/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0384 - accuracy: 0.9911 - val_loss: 0.1363 - val_accuracy: 0.9838
# Epoch 38/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0324 - accuracy: 0.9924 - val_loss: 0.1626 - val_accuracy: 0.9822
# Epoch 39/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0351 - accuracy: 0.9920 - val_loss: 0.1491 - val_accuracy: 0.9834
# Epoch 40/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0417 - accuracy: 0.9919 - val_loss: 0.1569 - val_accuracy: 0.9818
# Epoch 41/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0363 - accuracy: 0.9922 - val_loss: 0.1401 - val_accuracy: 0.9830
# Epoch 42/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0386 - accuracy: 0.9922 - val_loss: 0.1451 - val_accuracy: 0.9832
# Epoch 43/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0374 - accuracy: 0.9918 - val_loss: 0.1360 - val_accuracy: 0.9819
# Epoch 44/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0339 - accuracy: 0.9923 - val_loss: 0.1621 - val_accuracy: 0.9822
# Epoch 45/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0387 - accuracy: 0.9927 - val_loss: 0.1694 - val_accuracy: 0.9832
# Epoch 46/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0364 - accuracy: 0.9922 - val_loss: 0.1561 - val_accuracy: 0.9831
# Epoch 47/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0356 - accuracy: 0.9926 - val_loss: 0.1527 - val_accuracy: 0.9831
# Epoch 48/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0332 - accuracy: 0.9934 - val_loss: 0.1950 - val_accuracy: 0.9835
# Epoch 49/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0443 - accuracy: 0.9923 - val_loss: 0.1550 - val_accuracy: 0.9822
# Epoch 50/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0353 - accuracy: 0.9932 - val_loss: 0.1640 - val_accuracy: 0.9837
# CPU times: total: 1h 14min 46s
# Wall time: 16min 14s

# %%
model.save('mnist_dnn.h5')

# %%
model.evaluate(X_test,Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1948 - accuracy: 0.9843
# [0.19480189681053162, 0.9843000173568726]

# %%
# 혼동행렬
from sklearn.metrics import confusion_matrix
print('실제값:',y_test)
print('실제값:', np.argmax(Y_test, axis=1))
yhat = model.predict(X_test).argmax(axis=1)
cmatrix = confusion_matrix(y_test, yhat)
cmatrix
# Out:
# 실제값: [7 2 1 ... 4 5 6]
# 실제값: [7 2 1 ... 4 5 6]
# 313/313 [==============================] - 1s 4ms/step
# array([[ 975,    0,    0,    1,    0,    1,    1,    1,    1,    0],
#        [   0, 1131,    2,    0,    0,    0,    0,    0,    2,    0],
#        [   3,    0, 1020,    1,    0,    0,    0,    6,    2,    0],
#        [   0,    0,    6,  989,    0,    3,    0,    5,    3,    4],
#        [   1,    0,    2,    0,  963,    0,    5,    2,    1,    8],
#        [   5,    0,    0,    8,    1,  869,    2,    0,    3,    4],
#        [   6,    3,    0,    0,    4,    4,  939,    0,    2,    0],
#        [   1,    2,    9,    1,    0,    0,    0, 1006,    2,    7],
#        [   1,    0,    1,    2,    0,    3,    1,    3,  961,    2],
#        [   3,    2,    0,    4,    3,    1,    0,    4,    2,  990]],
#       dtype=int64)

# %%
# 실제값과 예측값이 다른 갯수(방법1)
cnt = 0
for i, row in enumerate(cmatrix):
    for j, data in enumerate(row):
        if i!=j:
            cnt += data
print('예측이 틀린 갯수 :', cnt)
# Out:
# 예측이 틀린 갯수 : 157

# %%
# 실제값과 예측값이 다르 갯수(방법2)
cnt = 0
for y, h in zip(y_test, yhat):
    if y!=h:
        cnt += 1
print('예측이 틀린 갯수 :', cnt)
# Out:
# 예측이 틀린 갯수 : 157

# %%
# CNN을 사용하여 예측이 틀린 데이터 출력(yhat과 y_test가 다른 것들 157개)
plt_row = 16
plt_col = 10
#plt.fugure(figsize=(plt_col, plt_row))
plt.rcParams['figure.figsize'] = [plt_col+3, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
#plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
plt.subplots_adjust(hspace=0.4, wspace=0.3)

i=0 #yhat과 y_test의 index => yhat[i], y_test[i]를 비교.
cnt=0 # 이미지 출력횟수

while (i<len(y_test)) & (cnt < plt_row*plt_col):
    if yhat[i]==y_test[i]:
        i += 1
        continue
    subax = axes[cnt//plt_col, cnt%plt_col] # //:몫연산자, %:나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = 'y:{}/h:{}({})'.format(y_test[i], yhat[i], i)
    subax.set_title(title)
    cnt += 1 #이미지 출력 번호 증가
    i += 1 #index 증가
#plt.tight_layout()

# %% [markdown]
# # CNN(컨볼루션 레이어 포함) -

# %%
# %%time
#1. 데이터 생성 및 전처리
width = 28; height=28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
#독립변수 (28*28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype('float32')/255.0
X_val = X_val.reshape(-1, width*height).astype('float32')/255.0
X_test = X_test.reshape(-1, width*height).astype('float32')/255.0
#타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# CPU times: total: 391 ms
# Wall time: 385 ms
# ((50000, 784), (50000,), (10000, 784), (10000,), (10000, 784), (10000,))
