# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# <font size="5" color="red">ch15 데이터베이스 연동</font>
# # 1. SQLite데이터 베이스 연동
# - SQLite 데이터베이스는 별도의 DBMS없이 SQL을 이용하여 DB엑세스 가능한 디스크 기반 DB
# - SQLite는 프로토타입(시제품) 용도
# - 프로젝트 단계 : 분석 - 설계 - 구현 - 테스트 - 고객에게 배포 - 유지보수
#                 SQLite    Orable/MySQL, MariaDB, mongoDB, ...
# - C라이브러리
# - [db browser for sqlite]

# %% [markdown]
# ## 1.1 SQLite패키지 load

# %%
import sqlite3
sqlite3.sqlite_version
# Out:
# '3.40.1'

# %% [markdown]
# ## 1.2 데이터베이스 연결

# %%
# DB 연결
conn = sqlite3.connect('data/ch15_exmple.db')
conn

# %%
# 커서객체(SQL문 실행->결과 조회) 생성
cursor = conn.cursor()
cursor

# %%
cursor.execute('''
    CREATE TABLE MEMBER(
        NAME TEXT,
        AGE  INT,
        EMAIL TEXT
    )
''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cursor.execute('''
#       2     CREATE TABLE MEMBER(
#       3         NAME TEXT,
#       4         AGE  INT,
#       5         EMAIL TEXT
#       6     )
#       7 ''')
#
# OperationalError: table MEMBER already exists

# %% [markdown]
# ### insert, update, delete전송

# %%
cursor.execute('''
    INSERT INTO MEMBER VALUES ('홍길동', 20, 'h@h.com')
''')
print('수행 결과 행수 :', cursor.rowcount)
# Out:
# 수행 결과 행수 : 1

# %%
sql = "INSERT INTO MEMBER VALUES ('김길동', 30, 'k@h.com')"
print(sql)
cursor.execute(sql)
print('수행 결과 행수 :', cursor.rowcount)
# Out:
# INSERT INTO MEMBER VALUES ('김길동', 30, 'k@h.com')
# 수행 결과 행수 : 1

# %%
conn.commit() # (반) conn.rollback() DML에서만 가능

# %% [markdown]
# ### select전송

# %%
cursor.execute('''
    SELECT NAME, AGE+1 NEXTAGE, EMAIL FROM MEMBER
''')

# %%
# SELECT 전송
#   select 문 실행결과를 받는 함수
#    cursor.fetchone() : 결과를 한행씩 받을 때(튜플)
#    cursor.fetchall() : 결과를 모두 받을 때 (튜플 list)
#    cursor.fetchmany(n) : 결과를 n행 받을 때(튜플 list)
#    cursor.description : header 내용을 포함한 내용들(list)

# INSERT, UPDATE, DELETE 전송 : cursor.rowcount
print(cursor.fetchall())
# Out:
# [('홍길동', 21, 'h@h.com'), ('홍길동', 21, 'h@h.com'), ('홍길동', 21, 'h@h.com'), ('홍길동', 21, 'h@h.com'), ('박길동', 31, 'k@h.com'), ('박길동', 31, 'k@h.com'), ('신길동', 31, 'k@h.com'), ('김길동', 31, 'k@h.com')]

# %%
cursor.execute('''
    SELECT NAME, AGE+1 NEXTAGE, EMAIL FROM MEMBER OEDER BY NEXTAGE
''')
members = cursor.fetchmany(3)
members
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 cursor.execute('''
#       2     SELECT NAME, AGE+1 NEXTAGE, EMAIL FROM MEMBER OEDER BY NEXTAGE
#       3 ''')
#       4 members = cursor.fetchmany(3)
#       5 members
#
# OperationalError: near "BY": syntax error

# %%
cursor.fetchall()
# Out:
# []

# %%
# 데이터 한줄씩 가져오기
cursor.execute('''
    SELECT NAME, AGE+1 NEXTAGE, EMAIL FROM MEMBER order by NEXTAGE
''')
members = []
while True:
    member = cursor.fetchone()
    if member is None:
        break
    print(member)
    members.append({'name':member[0], 'age':member[1], 'email':member[2]})
# Out:
# ('홍길동', 21, 'h@h.com')
# ('홍길동', 21, 'h@h.com')
# ('홍길동', 21, 'h@h.com')
# ('홍길동', 21, 'h@h.com')
# ('박길동', 31, 'k@h.com')
# ('박길동', 31, 'k@h.com')
# ('신길동', 31, 'k@h.com')
# ('김길동', 31, 'k@h.com')

# %%
import pandas as pd

# %%
cursor.execute('''
    SELECT NAME, AGE+1 NEXTAGE, EMAIL FROM MEMBER order by NEXTAGE
''')
members = cursor.fetchall()
df = pd.DataFrame(members)
df
# Out:
#      0   1        2
# 0  홍길동  21  h@h.com
# 1  홍길동  21  h@h.com
# 2  홍길동  21  h@h.com
# 3  홍길동  21  h@h.com
# 4  박길동  31  k@h.com
# 5  박길동  31  k@h.com
# 6  신길동  31  k@h.com
# 7  김길동  31  k@h.com

# %%
#select 문을 수행한 필드 정보
cursor.description
# Out:
# (('NAME', None, None, None, None, None, None),
#  ('NEXTAGE', None, None, None, None, None, None),
#  ('EMAIL', None, None, None, None, None, None))

# %%
[description[0] for description in cursor.description]
# Out:
# ['NAME', 'NEXTAGE', 'EMAIL']

# %% [markdown]
# ## 1.3 SQL구문에 파라미터 사용하기
# - qmark(DB에 따라 불가한 경우 있음)
# - named(추천)

# %%
conn = sqlite3.connect('data/ch15_exmple.db')
cursor = conn.cursor()
cursor.execute("SELECT * FROM MEMBER WHERE NAME IN ('홍길동', '김길동')")
cursor.fetchall()
# Out:
# [('홍길동', 20, 'h@h.com'),
#  ('홍길동', 20, 'h@h.com'),
#  ('홍길동', 20, 'h@h.com'),
#  ('홍길동', 20, 'h@h.com')]

# %%
# 파라미터 사용하기 : qmark 방법 이용
conn = sqlite3.connect('data/ch15_exmple.db')
cursor = conn.cursor()
sql = "SELECT * FROM MEMBER WHERE NAME IN (?, ?)"
name1 = input('검색할 이름은?')
name2 = input('검색할 다른이름은?')
cursor.execute(sql, (name1, name2))
cursor.fetchall()
# Out:
# 검색할 이름은?성춘향
# 검색할 다른이름은?홍길동
# [('홍길동', 20, 'h@h.com'),
#  ('홍길동', 20, 'h@h.com'),
#  ('홍길동', 20, 'h@h.com'),
#  ('홍길동', 20, 'h@h.com')]

# %%
# 파라미터 사용하기 : named 방법 이용
sql = "SELECT * FROM MEMBER WHERE NAME IN (:name1, :name2)"
name1 = input('검색할 이름은?')
name2 = input('검색할 다른이름은?')
cursor.execute(sql, {'name1':name1, 'name2':name2})
cursor.fetchall()
# Out:
# 검색할 이름은?홍길동
# 검색할 다른이름은?홍길동
# [('홍길동', 20, 'h@h.com'),
#  ('홍길동', 20, 'h@h.com'),
#  ('홍길동', 20, 'h@h.com'),
#  ('홍길동', 20, 'h@h.com')]

# %%
# named 방법으로 데이터 입력하기
try:
    name = input('입력할 이름은?')
    age = int(input('입력할 나이는?'))
except ValueError:
    print('유효하지 않은 나이를 입력하시면 18세로 초기화')
    age = 18
finally:
    email = input('입력할 메일은?')
cursor.execute('INSERT INTO MEMBER VALUES (:name, :age, :email)',
             {'name':name, 'age':age, 'email':email})
conn.commit()
if cursor.rowcount == 1:
    print('입력성공')
else:
    print('입력실패')
# Out:
# 입력할 이름은?이순신
# 입력할 나이는?54
# 입력할 메일은?lee@korea.com
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[52], line 10
#       8 finally:
#       9     email = input('입력할 메일은?')
# ---> 10 cursor.execute('INSERT INTO MEMBER VALUES (:name, :age, :email)',
#      11              {'name':name, 'age':age, 'email':email})
#      12 conn.commit()
#      13 if cursor.rowcount == 1:
#
# OperationalError: database is locked

# %% [markdown]
# - pip install cx_oracle

# %%
import cx_Oracle
#conn얻어오는 방법1
conn = cx_Oracle.connect('scott', 'tiger', 'localhost:1521/xe')
conn
# Out:
# <cx_Oracle.Connection to scott@localhost:1521/xe>

# %%
#conn얻어오는 방법2
oracle_dsn = cx_Oracle.makedsn(host='localhost', port=1521, sid="xe")
conn = cx_Oracle.connect("scott", "tiger", dsn=oracle_dsn)
conn
# Out:
# <cx_Oracle.Connection to scott@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=xe)))>

# %%
cursor = conn.cursor()
cursor.execute('SELECT EMPNO, ENAME, JOB, MGR, SAL, COMM FROM EMP')
emps = cursor.fetchall()
for emp in emps:
    print(emp)
# Out:
# (7369, 'SMITH', 'CLERK', 7902, 800.0, None)
# (7499, 'ALLEN', 'SALESMAN', 7698, 1600.0, 300.0)
# (7521, 'WARD', 'SALESMAN', 7698, 1250.0, 500.0)
# (7566, 'JONES', 'MANAGER', 7839, 2975.0, None)
# (7654, 'MARTIN', 'SALESMAN', 7698, 1250.0, 1400.0)
# (7698, 'BLAKE', 'MANAGER', 7839, 2850.0, None)
# (7782, 'CLARK', 'MANAGER', 7839, 2450.0, None)
# (7788, 'SCOTT', 'ANALYST', 7566, 3000.0, None)
# (7839, 'KING', 'PRESIDENT', None, 5000.0, None)
# (7844, 'TURNER', 'SALESMAN', 7698, 1500.0, 0.0)
# (7876, 'ADAMS', 'CLERK', 7788, 1100.0, None)
# (7900, 'JAMES', 'CLERK', 7698, 950.0, None)
# (7902, 'FORD', 'ANALYST', 7566, 3000.0, None)
# (7934, 'MILLER', 'CLERK', 7782, 1300.0, None)

# %%
pd.DataFrame(emps, 
            columns=[des[0] for des in cursor.description])
# Out:
#     EMPNO   ENAME        JOB     MGR     SAL    COMM
# 0    7369   SMITH      CLERK  7902.0   800.0     NaN
# 1    7499   ALLEN   SALESMAN  7698.0  1600.0   300.0
# 2    7521    WARD   SALESMAN  7698.0  1250.0   500.0
# 3    7566   JONES    MANAGER  7839.0  2975.0     NaN
# 4    7654  MARTIN   SALESMAN  7698.0  1250.0  1400.0
# 5    7698   BLAKE    MANAGER  7839.0  2850.0     NaN
# 6    7782   CLARK    MANAGER  7839.0  2450.0     NaN
# 7    7788   SCOTT    ANALYST  7566.0  3000.0     NaN
# 8    7839    KING  PRESIDENT     NaN  5000.0     NaN
# 9    7844  TURNER   SALESMAN  7698.0  1500.0     0.0
# 10   7876   ADAMS      CLERK  7788.0  1100.0     NaN
# 11   7900   JAMES      CLERK  7698.0   950.0     NaN
# 12   7902    FORD    ANALYST  7566.0  3000.0     NaN
# 13   7934  MILLER      CLERK  7782.0  1300.0     NaN
