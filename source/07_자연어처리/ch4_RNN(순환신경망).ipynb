# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# **<font size="6" color="red">ch4. RNN(Recurrent Neural Network) 순환신경망</font>**

# %% [markdown]
# # 1. 문맥을 이용하여 모델만들기

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다
"""
text1 = "장마철이 오고 있다"

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text, text1])
encoded = t.texts_to_sequences([text, text1])
print(encoded)
print(t.word_index)
# Out:
# [[3, 4, 1, 5, 2, 6, 1, 7, 8, 1, 9, 10, 1, 11], [12, 13, 2]]
# {'말이': 1, '있다': 2, '경마장에': 3, '있는': 4, '뛰고': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11, '장마철이': 12, '오고': 13}

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text])
encoded = t.texts_to_sequences([text])
print(encoded)
print(t.word_index)
# Out:
# [[2, 3, 1, 4, 5, 6, 1, 7, 8, 1, 9, 10, 1, 11]]
# {'말이': 1, '경마장에': 2, '있는': 3, '뛰고': 4, '있다': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11}

# %%
#문자열 리스트를 인덱스 시퀀스로 변환
print(t.texts_to_sequences(['경마장에 말이 있다', '말이 뛴다']))
print(t.texts_to_sequences(['가는 말이 곱다']))
# Out:
# [[2, 1, 5], [1]]
# [[8, 1, 11]]

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""

# %%
for key, value in t.word_index.items():
    print(key, value)
# Out:
# 말이 1
# 경마장에 2
# 있는 3
# 뛰고 4
# 있다 5
# 그의 6
# 법이다 7
# 가는 8
# 고와야 9
# 오는 10
# 곱다 11

# %%
# 학습을 시키기 위해 ['경마장에 있는', '경마장에 있는 말이', ...]
sequences = []
for line in text.split('\n'):
    print('원문장 :', line)
    encoded = t.texts_to_sequences([line])[0]
    print('encoded된 문장 :', encoded)
    for i in range(0, len(encoded)-1): #i:시작index
        for j in range(i+2, len(encoded)+1): #j:끝나는 인덱스 바로 뒤
            sequences.append(encoded[i:j])
print('sequences와 해석 출력')
for sequence in sequences:
    for word_seq in sequence:
        for word, id in t.word_index.items():
            if word_seq==id:
                print("{}:{}".format(word_seq, word), end=' ')
                break
    print()
# Out:
# 원문장 : 경마장에 있는 말이 뛰고 있다
# encoded된 문장 : [2, 3, 1, 4, 5]
# 원문장 : 그의 말이 법이다
# encoded된 문장 : [6, 1, 7]
# 원문장 : 가는 말이 고와야 오는 말이 곱다
# encoded된 문장 : [8, 1, 9, 10, 1, 11]
# sequences와 해석 출력
# 2:경마장에 3:있는
# 2:경마장에 3:있는 1:말이
# 2:경마장에 3:있는 1:말이 4:뛰고
# 2:경마장에 3:있는 1:말이 4:뛰고 5:있다
# 3:있는 1:말이
# 3:있는 1:말이 4:뛰고
# 3:있는 1:말이 4:뛰고 5:있다
# 1:말이 4:뛰고
# 1:말이 4:뛰고 5:있다
# 4:뛰고 5:있다
# 6:그의 1:말이
# 6:그의 1:말이 7:법이다
# 1:말이 7:법이다
# 8:가는 1:말이
# 8:가는 1:말이 9:고와야
# 8:가는 1:말이 9:고와야 10:오는
# 8:가는 1:말이 9:고와야 10:오는 1:말이
# 8:가는 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 1:말이 9:고와야
# 1:말이 9:고와야 10:오는
# 1:말이 9:고와야 10:오는 1:말이
# 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 9:고와야 10:오는
# 9:고와야 10:오는 1:말이
# 9:고와야 10:오는 1:말이 11:곱다
# 10:오는 1:말이
# 10:오는 1:말이 11:곱다
# 1:말이 11:곱다

# %%
print([len(sequence) for sequence in sequences])
my_len = max([len(sequence) for sequence in sequences])
my_len
# Out:
# [2, 3, 4, 5, 2, 3, 4, 2, 3, 2, 2, 3, 2, 2, 3, 4, 5, 6, 2, 3, 4, 5, 2, 3, 4, 2, 3, 2]
# 6

# %%
# sequences를 훈련 가능하도록 모두 6개로 조정
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequences = pad_sequences(sequences=sequences,
                                maxlen=my_len,
                                padding='pre'
                                #padding='post'
                                )
#padded_sequences
padded_sequences.shape, type(padded_sequences)
# Out:
# ((28, 6), numpy.ndarray)

# %%
#독립변수(X)와 타겟변수(y)로 분리
X = padded_sequences[:, :-1]
y = padded_sequences[:, -1]
y
# Out:
# array([ 3,  1,  4,  5,  1,  4,  5,  4,  5,  5,  1,  7,  7,  1,  9, 10,  1,
#        11,  9, 10,  1, 11, 10,  1, 11,  1, 11, 11])

# %%
#컴퓨터가 임베딩 작업할 때 필요한 단어 갯수
len(t.word_index)+1
# Out:
# {'말이': 1,
#  '경마장에': 2,
#  '있는': 3,
#  '뛰고': 4,
#  '있다': 5,
#  '그의': 6,
#  '법이다': 7,
#  '가는': 8,
#  '고와야': 9,
#  '오는': 10,
#  '곱다': 11}

# %%
# X를 임베딩 작업할 때 필요한 입력 bit수 (단어수+1)
input_dim = len(t.word_index)+1
input_dim
# Out:
# 12

# %%
#y의 원핫인코딩
from tensorflow.keras.utils import to_categorical
Y = to_categorical(y, input_dim)
X.shape, Y.shape, input_dim
# Out:
# ((28, 5), (28, 12), 12)

# %%
# 2. 모델 생성하기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding #Xi의 원핫인코딩한 희소행렬 변환
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt

model = Sequential()
model.add(Embedding(input_dim=input_dim, #12개로 원핫인코딩
                   output_dim=10, #임베딩 출력의 갯수
                   input_length=X.shape[1])) #입력(X)의 수
model.add(SimpleRNN(units=32))
model.add(Dense(12, activation='softmax'))
print(model.summary())
#3. 모델 학습 과정 설정
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 4. 모델 학습시키기
hist = model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 5, 10)             120
#
#  simple_rnn_4 (SimpleRNN)    (None, 32)                1376
#
#  dense_4 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 1,892
# Trainable params: 1,892
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 1/1 - 1s - loss: 2.4934 - accuracy: 0.0357 - 1s/epoch - 1s/step
# Epoch 2/300
# 1/1 - 0s - loss: 2.4834 - accuracy: 0.0357 - 4ms/epoch - 4ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 2.4734 - accuracy: 0.0357 - 6ms/epoch - 6ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 2.4636 - accuracy: 0.2143 - 5ms/epoch - 5ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 2.4537 - accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 2.4436 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 2.4334 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 2.4230 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 2.4123 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 2.4012 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 2.3897 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 2.3778 - accuracy: 0.4286 - 6ms/epoch - 6ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 2.3654 - accuracy: 0.4286 - 5ms/epoch - 5ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 2.3525 - accuracy: 0.3929 - 6ms/epoch - 6ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 2.3391 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 2.3251 - accuracy: 0.3929 - 4ms/epoch - 4ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 2.3105 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 2.2953 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 2.2795 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 2.2632 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 2.2463 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 2.2288 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 2.2110 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 2.1927 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 2.1741 - accuracy: 0.3571 - 7ms/epoch - 7ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 2.1554 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 2.1365 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 2.1177 - accuracy: 0.3571 - 11ms/epoch - 11ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 2.0991 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 2.0808 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 2.0629 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 2.0455 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 2.0286 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 2.0124 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 1.9967 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 1.9817 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 1.9671 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 1.9529 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 1.9391 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 1.9256 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 1.9122 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 1.8990 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 1.8859 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 1.8730 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 1.8601 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 1.8475 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 1.8350 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 1.8227 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 1.8105 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 1.7984 - accuracy: 0.4286 - 5ms/epoch - 5ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 1.7865 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 1.7745 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 1.7626 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 1.7506 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 1.7384 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 1.7262 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 1.7137 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 1.7012 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 1.6884 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 1.6755 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 1.6624 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 1.6491 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 1.6357 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 1.6222 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 1.6085 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 1.5946 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 1.5806 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 1.5665 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 1.5523 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 1.5379 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 1.5235 - accuracy: 0.5000 - 14ms/epoch - 14ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 1.5090 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 1.4945 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 1.4800 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 1.4655 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 1.4511 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 1.4367 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 1.4224 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 1.4081 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 1.3940 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 1.3800 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 1.3660 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 1.3522 - accuracy: 0.5357 - 6ms/epoch - 6ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 1.3385 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 1.3249 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 1.3115 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 1.2982 - accuracy: 0.5714 - 6ms/epoch - 6ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 1.2850 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 1.2719 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 1.2589 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 1.2461 - accuracy: 0.5714 - 6ms/epoch - 6ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 1.2335 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 1.2209 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 1.2085 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 1.1962 - accuracy: 0.6071 - 6ms/epoch - 6ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 1.1841 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 1.1720 - accuracy: 0.6071 - 5ms/epoch - 5ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 1.1601 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 1.1484 - accuracy: 0.6071 - 5ms/epoch - 5ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 1.1367 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 1.1252 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 1.1138 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 1.1025 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 1.0914 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 1.0803 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 1.0694 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 1.0586 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 1.0480 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 1.0375 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 1.0270 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 1.0167 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 1.0066 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 0.9965 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.9866 - accuracy: 0.6786 - 6ms/epoch - 6ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.9768 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.9671 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.9575 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.9481 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.9387 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.9295 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.9204 - accuracy: 0.7143 - 6ms/epoch - 6ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.9114 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.9025 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.8937 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.8850 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.8765 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.8680 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.8596 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.8514 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.8432 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.8351 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.8272 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.8193 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.8115 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.8038 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.7962 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.7887 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.7813 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.7740 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.7667 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.7595 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.7525 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.7455 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.7385 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.7317 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.7250 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.7183 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.7117 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.7052 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.6988 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.6924 - accuracy: 0.8214 - 16ms/epoch - 16ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.6861 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.6799 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.6738 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.6678 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.6618 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.6559 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.6501 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.6443 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.6386 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.6330 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.6275 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.6220 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.6166 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.6113 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.6060 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.6008 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.5957 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.5907 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.5857 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.5807 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.5759 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.5711 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.5664 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.5617 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.5571 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.5525 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.5481 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.5436 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.5393 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.5350 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.5307 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.5265 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.5224 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.5183 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.5143 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.5103 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.5064 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.5025 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.4987 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.4950 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.4913 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.4876 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.4840 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.4804 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.4769 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.4735 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.4700 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.4667 - accuracy: 0.8571 - 7ms/epoch - 7ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.4633 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.4601 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.4568 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.4536 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.4505 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.4474 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.4443 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.4413 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.4383 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.4354 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.4325 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.4296 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.4268 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.4240 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.4213 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.4186 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.4159 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.4133 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.4107 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.4081 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.4056 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.4031 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.4007 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.3982 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.3958 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.3935 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.3912 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.3889 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.3866 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.3844 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.3822 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.3801 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.3779 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.3758 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.3738 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.3717 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.3697 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.3677 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.3657 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.3638 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.3619 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.3600 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.3582 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.3564 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.3546 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.3528 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.3510 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.3493 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.3459 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.3443 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.3426 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.3410 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.3394 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.3379 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.3363 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.3348 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.3333 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.3318 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.3304 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.3289 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.3275 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.3261 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.3247 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.3233 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.3220 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.3207 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.3194 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.3181 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.3168 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.3155 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.3143 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.3130 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.3118 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.3106 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.3094 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.3083 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.3071 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.3060 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.3049 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.3037 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.3026 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.3016 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.3005 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.2994 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.2984 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.2973 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.2963 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.2953 - accuracy: 0.8929 - 12ms/epoch - 12ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.2943 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.2933 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.2924 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.2914 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.2905 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.2895 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.2886 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.2877 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.2868 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.2859 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.2850 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.2841 - accuracy: 0.8929 - 5ms/epoch - 5ms/step

# %%
# 5. 모델 학습 과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='upper left')
plt.show()

# %%
# 모델 사용하기(경마장에 있는 말이 -> 뛰고)
input_word = input('입력단어 :')
encoded = t.texts_to_sequences([input_word])[0]
input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
print('입력 데이터 :', input_data)
result = model.predict(input_data, verbose=0).argmax()
word = t.index_word.get(result, '??')
#word = t.index_word[result]
print('예측된 단어 :', word)
# Out:
# 입력단어 :가는
# 입력 데이터 : [[0 0 0 0 8]]
# 예측된 단어 : 말이

# %%
t.texts_to_sequences(['없는 단어'])
# Out:
# [[]]

# %% [markdown]
# # 2. 다음 문맥 예측해 보기

# %%
# "경마장에" 이후에 올 단어 3개 예측 -> 경마장에 있는 말이 뛰고
def sentence_generation(current_word, n):
    #print('입력된 단어 :', current_word)
    for i in range(1, n+1):
        encoded = t.texts_to_sequences([current_word])[0]
        input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
        result = model.predict(input_data, verbose=0).argmax()
        word = t.index_word[result]
        current_word = current_word + ' ' + word
#         print('{}번째 생성 문맥 {} ({}{}) : '.format(i,
#                                                current_word,
#                                               encoded, result))
    return current_word
sentence_generation('경마장에', 3)
# Out:
# '경마장에 있는 말이 뛰고'

# %%
sentence_generation('가는', 2)
# Out:
# '가는 말이 고와야'
